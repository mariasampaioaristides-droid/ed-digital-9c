# %% [markdown]
# <a href="https://colab.research.google.com/github/mariasampaioaristides-droid/ed-digital-9c/blob/main/quiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Quiz de Agricultura
#
# Este é um quiz sobre agricultura! Você terá 10 perguntas e precisará acertar todas para ganhar o jogo. Se errar uma única pergunta, o jogo termina. Boa sorte!

# %%
import random

# Banco de 30 perguntas sobre agricultura
questions = [
    {
        "question": "Qual é o cereal mais cultivado no mundo?",
        "options": {"a": "Arroz", "b": "Milho"},
        "answer": "b"
    },
    {
        "question": "Qual fertilizante é essencial para o crescimento das plantas e é representado pela letra 'N' na sigla NPK?",
        "options": {"a": "Potássio", "b": "Nitrogênio"},
        "answer": "b"
    },
    {
        "question": "Qual é o nome da técnica de cultivo de plantas sem solo, usando soluções nutritivas em água?",
        "options": {"a": "Hidroponia", "b": "Aquaponia"},
        "answer": "a"
    },
    {
        "question": "Qual inseto é conhecido por polinizar diversas culturas agrícolas?",
        "options": {"a": "Mosquito", "b": "Abelha"},
        "answer": "b"
    },
    {
        "question": "A rotação de culturas é uma prática agrícola que ajuda a:",
        "options": {"a": "Esgotar o solo", "b": "Melhorar a fertilidade do solo"},
        "answer": "b"
    },
    {
        "question": "Qual desses é um grão leguminoso importante para a alimentação e para a fixação de nitrogênio no solo?",
        "options": {"a": "Soja", "b": "Trigo"},
        "answer": "a"
    },
    {
        "question": "Qual o principal fator que influencia a escolha de uma cultura para plantio em determinada região?",
        "options": {"a": "Cor da semente", "b": "Clima e solo"},
        "answer": "b"
    },
    {
        "question": "Qual o nome da estrutura que armazena os grãos após a colheita?",
        "options": {"a": "Estufa", "b": "Silo"},
        "answer": "b"
    },
    {
        "question": "Qual o objetivo principal do controle de pragas na agricultura?",
        "options": {"a": "Aumentar a população de insetos", "b": "Proteger a lavoura e otimizar a produção"},
        "answer": "b"
    },
    {
        "question": "Qual o principal insumo orgânico utilizado para adubar o solo?",
        "options": {"a": "Adubo químico", "b": "Composto orgânico"},
        "answer": "b"
    },
    {
        "question": "Qual o principal gás estufa liberado pela pecuária?",
        "options": {"a": "Dióxido de carbono", "b": "Metano"},
        "answer": "b"
    },
    {
        "question": "Qual prática agrícola ajuda a prevenir a erosão do solo em encostas?",
        "options": {"a": "Plantio em linha reta", "b": "Curvas de nível"},
        "answer": "b"
    },
    {
        "question": "Qual é o principal uso da cana-de-açúcar no Brasil?",
        "options": {"a": "Fabricação de papel", "b": "Produção de açúcar e etanol"},
        "answer": "b"
    },
    {
        "question": "Qual o nome da técnica de melhoramento genético que consiste na seleção artificial de plantas e animais?",
        "options": {"a": "Clonagem", "b": "Cruzamento"},
        "answer": "b"
    },
    {
        "question": "Qual o tipo de irrigação mais eficiente para economizar água?",
        "options": {"a": "Aspersão", "b": "Gotejamento"},
        "answer": "b"
    },
    {
        "question": "Qual a principal diferença entre agricultura orgânica e convencional?",
        "options": {"a": "Uso de sementes transgênicas", "b": "Não uso de agrotóxicos e fertilizantes sintéticos"},
        "answer": "b"
    },
    {
        "question": "Qual a importância das minhocas para o solo agrícola?",
        "options": {"a": "Compactar o solo", "b": "Aerar e enriquecer o solo"},
        "answer": "b"
    },
    {
        "question": "Qual o nome da fase do ciclo da planta em que ela produz flores?",
        "options": {"a": "Fase vegetativa", "b": "Fase reprodutiva"},
        "answer": "b"
    },
    {
        "question": "Qual o nome da ferramenta utilizada para arar a terra?",
        "options": {"a": "Foice", "b": "Arado"},
        "answer": "b"
    },
    {
        "question": "Qual o nome da doença que afeta as plantas e é causada por fungos?",
        "options": {"a": "Câncer", "b": "Ferrugem"},
        "answer": "b"
    },
    {
        "question": "Qual o nome do processo de transformação de matéria orgânica em adubo?",
        "options": {"a": "Putrefação", "b": "Compostagem"},
        "answer": "b"
    },
    {
        "question": "Qual o principal benefício da agricultura de precisão?",
        "options": {"a": "Reduzir o controle sobre a lavoura", "b": "Otimizar o uso de recursos e aumentar a produtividade"},
        "answer": "b"
    },
    {
        "question": "Qual o nome do sistema de criação de animais que integra a agricultura?",
        "options": {"a": "Pecuária extensiva", "b": "Integração Lavoura-Pecuária-Floresta (ILPF)"},
        "answer": "b"
    },
    {
        "question": "Qual o nome da técnica de poda que visa aumentar a produtividade das árvores frutíferas?",
        "options": {"a": "Poda de formação", "b": "Poda de produção"},
        "answer": "b"
    },
    {
        "question": "Qual o nome da ciência que estuda o solo?",
        "options": {"a": "Biologia", "b": "Pedologia"},
        "answer": "b"
    },
    {
        "question": "Qual o principal objetivo do preparo do solo antes do plantio?",
        "options": {"a": "Compactar o solo", "b": "Melhorar a estrutura e disponibilidade de nutrientes"},
        "answer": "b"
    },
    {
        "question": "Qual o nome do equipamento utilizado para semear as sementes?",
        "options": {"a": "Colheitadeira", "b": "Plantadeira"},
        "answer": "b"
    },
    {
        "question": "Qual o nome da prática de plantar árvores em conjunto com culturas agrícolas?",
        "options": {"a": "Monocultura", "b": "Agrofloresta"},
        "answer": "b"
    },
    {
        "question": "Qual o nome da técnica de colheita que utiliza máquinas?",
        "options": {"a": "Colheita manual", "b": "Colheita mecanizada"},
        "answer": "b"
    },
    {
        "question": "Qual o nome do processo de remoção de plantas daninhas da lavoura?",
        "options": {"a": "Adubação", "b": "Capina"},
        "answer": "b"
    }
]

# %%
# Sortear 10 perguntas
selected_questions = random.sample(questions, 10)

correct_answers_count = 0
game_over = False

print("\n--- Início do Quiz ---\n")

for i, q in enumerate(selected_questions):
    print(f"Pergunta {i + 1}: {q['question']}")
    print(f"A) {q['options']['a']}")
    print(f"B) {q['options']['b']}")

    user_answer = input("Sua resposta (A ou B): ").strip().lower()

    if user_answer == q['answer']:
        print("Correto!\n")
        correct_answers_count += 1
    else:
        print(f"Errado! A resposta correta era '{q['answer'].upper()}'.\n")
        game_over = True
        break

if game_over:
    print("Você errou uma pergunta. O jogo terminou! Tente novamente.")
else:
    print(f"Parabéns! Você acertou todas as {correct_answers_count} perguntas e ganhou o jogo!")

print("\n--- Fim do Quiz ---")
# Out:
# --- Início do Quiz ---
#
# Pergunta 1: Qual o principal insumo orgânico utilizado para adubar o solo?
# A) Adubo químico
# B) Composto orgânico
